# %%
import pandas as pd

df = pd.read_csv("../data/data.csv")
df.head()
# Out:
#                                 User ID                   Timestamp  Age  \
# 0  2ca88c4f-dfe5-4207-a004-e5a902c5f0e7  2025-01-20 06:18:52.887014   25
# 1  2382edc6-39f2-409f-a154-257331feed33  2025-11-13 06:18:52.887187   21
# 2  a65b87bb-1b29-42df-9542-1140e131b94f  2025-11-10 06:18:52.887294   18
# 3  b0c2edb4-0b17-4d02-96fd-ded977e7b9df  2025-05-26 06:18:52.887379   45
# 4  38d0bd2f-4722-472a-af2e-f2a9773d547f  2025-07-25 06:18:52.887454   43
#
#    Gender   Location                       Languages Spoken  \
# 0    Male    Lucknow               English, Telugu, Punjabi
# 1  Female    Lucknow  Punjabi, Gujarati, Malayalam, English
# 2    Male     Jaipur                Tamil, Kannada, Punjabi
# 3   Other    Chennai              Telugu, Gujarati, Bengali
# 4   Other  Hyderabad                              Malayalam
#
#    Class 10 Percentage  Class 12 Percentage Class 12 Stream Graduate Major  \
# 0                85.27                64.09            Arts            BBA
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 48 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   User ID                  400 non-null    object
#  1   Timestamp                400 non-null    object
#  2   Age                      400 non-null    int64
#  3   Gender                   400 non-null    object
#  4   Location                 400 non-null    object
#  5   Languages Spoken         400 non-null    object
#  6   Class 10 Percentage      400 non-null    float64
#  7   Class 12 Percentage      400 non-null    float64
#  8   Class 12 Stream          400 non-null    object
#  9   Graduate Major           400 non-null    object
#  10  Graduate CGPA            400 non-null    float64
#  11  PG Major                 311 non-null    object
#  12  PG CGPA                  400 non-null    float64
#  13  Highest Education        400 non-null    object
# ...

# %%
df.isnull().sum()
# Out:
# User ID                     0
# Timestamp                   0
# Age                         0
# Gender                      0
# Location                    0
# Languages Spoken            0
# Class 10 Percentage         0
# Class 12 Percentage         0
# Class 12 Stream             0
# Graduate Major              0
# Graduate CGPA               0
# PG Major                   89
# PG CGPA                     0
# Highest Education           0
# Academic Consistency        0
# Technical Skills            0
# Tech Skill Proficiency      0
# Soft Skills                 0
# Soft Skill Proficiency      0
# Skill Embedding             0
# Courses Completed           0
# Avg Course Difficulty       0
# Total Hours Learning        0
# Course Keywords             0
# Project Count               0
# Avg Project Complexity      0
# Project Keywords            0
# Experience Months           0
# Experience Types            0
# Job Level                   0
# Work Keywords               0
# ...

# %%
df.nunique()
# Out:
# User ID                    400
# Timestamp                  400
# Age                         33
# Gender                       3
# Location                    16
# Languages Spoken           273
# Class 10 Percentage        383
# Class 12 Percentage        388
# Class 12 Stream              3
# Graduate Major               8
# Graduate CGPA              219
# PG Major                     4
# PG CGPA                    211
# Highest Education           15
# Academic Consistency        61
# Technical Skills             5
# Tech Skill Proficiency       8
# Soft Skills                  3
# Soft Skill Proficiency      51
# Skill Embedding              1
# Courses Completed           31
# Avg Course Difficulty        5
# Total Hours Learning       285
# Course Keywords              1
# Project Count               13
# Avg Project Complexity       5
# Project Keywords             1
# Experience Months          174
# Experience Types            16
# Job Level                    3
# ...
